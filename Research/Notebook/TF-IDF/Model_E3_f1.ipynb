# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# Data Analysis
import pandas as pd
import numpy as np
from numpy import asarray
from numpy import savetxt
from numpy import loadtxt
import pickle as pkl
from scipy import sparse

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# %%
# loading data
df = pd.read_csv('/content/data1_3.csv')
pd.DataFrame(df)
# Out:
#                                              Indikator Tipe
# 0    hanya membagikan hal tersebut kepada orang-ora...    I
# 1                                           tidak suka    I
# 2    Biasanya saya akan membagikan hal tersebut kep...    I
# 3                                 Orang tertentu doang    I
# 4                         Orang-orang tertentu. Sering    I
# ..                                                 ...  ...
# 120  Jika saya memiliki sebuah tujuan/rencana, saya...    I
# 121  Menurut saya, saya merupakan tipe orang yang o...    E
# 122  Saya jarang upload di media sosial, saya kalau...    I
# 123  saya suka dan sering bercerita tentang diri sa...    E
# 124  Biasanya hanya menceritakan kepada orang-orang...    I
#
# [125 rows x 2 columns]

# %%
#  memeriksa missing value
df.isnull().sum()
# Out:
# Indikator    0
# Tipe         0
# dtype: int64

# %%
df.describe(include=['object'])
# Out:
#                                                 Indikator Tipe
# count                                                 125  125
# unique                                                125    2
# top     hanya membagikan hal tersebut kepada orang-ora...    I
# freq                                                    1  100

# %%
total = df.groupby(['Tipe']).count()
total
# Out:
#       Indikator
# Tipe
# E            25
# I           100

# %%
#Mencari kata terumum pada kolom indikator
from collections import Counter

words = list(df["Indikator"].apply(lambda x: x.split()))
words = [x for y in words for x in y]
Counter(words).most_common(100)
# Out:
# [('saya', 182),
#  ('orang', 106),
#  ('kepada', 69),
#  ('membagikan', 57),
#  ('yang', 53),
#  ('rencana', 52),
#  ('dan', 49),
#  ('tidak', 47),
#  ('hanya', 43),
#  ('tertentu', 40),
#  ('sering', 37),
#  ('suka', 32),
#  ('hal', 30),
#  ('tersebut', 30),
#  ('atau', 30),
#  ('akan', 29),
#  ('untuk', 29),
#  ('ke', 28),
#  ('lebih', 28),
#  ('dengan', 26),
#  ('Saya', 24),
#  ('di', 23),
#  ('saja', 22),
#  ('orang-orang', 21),
#  ('karena', 21),
#  ('jika', 19),
#  ('tujuan', 18),
#  ('terdekat', 16),
#  ('sendiri', 16),
#  ('jarang', 15),
#  ('itu', 15),
#  ('teman', 14),
#  ('seperti', 14),
#  ('lain', 14),
#  ('tertentu,', 13),
#  ('saya,', 12),
#  ('dekat', 12),
#  ('membagikannya', 12),
#  ('biasanya', 11),
#  ('terlalu', 10),
#  ('tujuan/rencana', 10),
#  ('Hanya', 9),
#  ('bercerita', 9),
#  ('bisa', 9),
#  ('saja,', 9),
#  ('media', 9),
#  ('tertentu.', 8),
#  ('tapi', 8),
#  ('ada', 8),
#  ('namun', 8),
#  ('nya', 8),
#  ('sosial', 8),
#  ('memiliki', 7),
#  ('saya.', 7),
#  ('juga', 7),
#  ('melakukan', 7),
#  ('kalau', 7),
#  ('beberapa', 6),
#  ('sudah', 6),
#  ('depan', 6),
#  ('sangat', 6),
#  ('cenderung', 6),
#  ('pernah', 6),
#  ('diri', 6),
#  ('pribadi', 6),
#  ('penting', 5),
#  ('bagikan', 5),
#  ('bersifat', 5),
#  ('mereka', 5),
#  ('Jika', 5),
#  ('sebuah', 5),
#  ('percaya', 5),
#  ('menurut', 5),
#  ('apa', 5),
#  ('menunjukkan', 5),
#  ('orang"', 5),
#  ('mungkin', 5),
#  ('tetapi', 5),
#  ('menceritakan', 5),
#  ('saja.', 5),
#  ('apabila', 5),
#  ('tentang', 5),
#  ('Orang', 4),
#  ('private', 4),
#  ('berbagi', 4),
#  ('sekali', 4),
#  ('tua', 4),
#  ('ceritakan', 4),
#  ('keluarga', 4),
#  ('sahabat', 4),
#  ('merupakan', 4),
#  ('semua', 4),
#  ('cerita', 4),
#  ('karna', 4),
#  ('kecuali', 4),
#  ('masa', 4),
#  ('kedepannya', 4),
#  ('tergantung', 4),
#  ('ini', 3),
#  ('Sering', 3)]

# %% [markdown]
# #Data Pre-processing
#
# 1. Case Folding
# 2. Data Cleansing
# - Case folding
# - Stripping
# - Remove emoji
# - Remove number
# - Remove character
# - Remove punctiation
# - Remove single char
# 3. Tokenizing
# 4. Normalization
# 5. Filtering
# 6. Stemming

# %%
# Text Processing
import re
import itertools
import string
import collections
from collections import Counter
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
df['Indikator'] = df['Indikator'].str.lower()
pd.DataFrame(df['Indikator'])
# Out:
#                                              Indikator
# 0    hanya membagikan hal tersebut kepada orang-ora...
# 1                                           tidak suka
# 2    biasanya saya akan membagikan hal tersebut kep...
# 3                                 orang tertentu doang
# 4                         orang-orang tertentu. sering
# ..                                                 ...
# 120  jika saya memiliki sebuah tujuan/rencana, saya...
# 121  menurut saya, saya merupakan tipe orang yang o...
# 122  saya jarang upload di media sosial, saya kalau...
# 123  saya suka dan sering bercerita tentang diri sa...
# 124  biasanya hanya menceritakan kepada orang-orang...
#
# [125 rows x 1 columns]

# %%
# data cleansing
from IPython.utils import text
import string
import re #regex library

# Import word_tokennize & FreqDist from NLTK
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

def data_clean(indikator) :
  #remove tab. new line, and back slice
  indikator = indikator.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
  #remove non ASCII (emoticon,dll)
  indikator = indikator.encode('ascii', 'replace').decode('ascii')
  #remove mention, link, hashtag
  indikator = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", indikator).split())
  #remove number
  indikator = re.sub(r"\d+", "", indikator)
  #remove punctuation
  indikator = indikator.translate(str.maketrans("","",string.punctuation))
  #remove whitespace leading & trailing
  indikator =  indikator.strip()
  #remove multiple white spacew into single white space
  indikator = re.sub('\s+', ' ', indikator)
  #remove single char
  indikator = re.sub(r"\b[a-zA-Z]\b", "", indikator)

  return indikator
df['Indikator_clean'] = df['Indikator'].apply(data_clean)
  #NLTK word tokenize
def word_tokenize_wrapper(indikator) :
  return word_tokenize(indikator)

df['Indikator_tokens'] = df['Indikator_clean'].apply(word_tokenize_wrapper)

pd.DataFrame(df)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                              Indikator Tipe  \
# 0    hanya membagikan hal tersebut kepada orang-ora...    I
# 1                                           tidak suka    I
# 2    biasanya saya akan membagikan hal tersebut kep...    I
# 3                                 orang tertentu doang    I
# 4                         orang-orang tertentu. sering    I
# ..                                                 ...  ...
# 120  jika saya memiliki sebuah tujuan/rencana, saya...    I
# 121  menurut saya, saya merupakan tipe orang yang o...    E
# 122  saya jarang upload di media sosial, saya kalau...    I
# 123  saya suka dan sering bercerita tentang diri sa...    E
# 124  biasanya hanya menceritakan kepada orang-orang...    I
#
#                                        Indikator_clean  \
# 0    hanya membagikan hal tersebut kepada orangoran...
# 1                                           tidak suka
# 2    biasanya saya akan membagikan hal tersebut kep...
# 3                                 orang tertentu doang
# 4                           orangorang tertentu sering
# ..                                                 ...
# 120  jika saya memiliki sebuah tujuanrencana saya l...
# 121  menurut saya saya merupakan tipe orang yang ov...
# 122  saya jarang upload di media sosial saya kalau ...
# 123  saya suka dan sering bercerita tentang diri sa...
# 124  biasanya hanya menceritakan kepada orangorang ...
#
#                                       Indikator_tokens
# 0    [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                        [tidak, suka]
# 2    [biasanya, saya, akan, membagikan, hal, terseb...
# 3                             [orang, tertentu, doang]
# 4                       [orangorang, tertentu, sering]
# ..                                                 ...
# 120  [jika, saya, memiliki, sebuah, tujuanrencana, ...
# 121  [menurut, saya, saya, merupakan, tipe, orang, ...
# 122  [saya, jarang, upload, di, media, sosial, saya...
# 123  [saya, suka, dan, sering, bercerita, tentang, ...
# 124  [biasanya, hanya, menceritakan, kepada, orango...
#
# [125 rows x 4 columns]

# %%
normalizad_word = pd.read_csv("normalisasi1.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['Indikator_normalized'] = df['Indikator_tokens'].apply(normalized_term)

df['Indikator_normalized'].head()
# Out:
# 0    [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                        [tidak, suka]
# 2    [biasanya, saya, akan, membagikan, hal, terseb...
# 3                             [orang, tertentu, doang]
# 4                       [orangorang, tertentu, sering]
# Name: Indikator_normalized, dtype: object

# %%
# # filtering
# import nltk
# from nltk.corpus import stopwords
# nltk.download('stopwords')


# def stopword_removal (indikator):
#   filtering = stopwords.words('indonesian','english')
#   x = []
#   data = []
#   def my_func (x) :
#     if x in filtering :
#       return False
#     else :
#       return True

#   fit = filter(my_func,indikator)
#   for x in fit :
#     data.append(x)
#   return data

# df['indikator_filter'] = df['Indikator_normalized'].apply(stopword_removal)
# df['indikator_filter'].head()

# %%
# Membuat list stopword sesuai kebutuhan fitur berdasarkan most uninformative words
'''
Ketika ada PR yang harus diselesaikan malam ini, Tiba-tiba teman lamamu mengajak
kamu untuk bertemu (reuni,bermain, ngobrol). Bagaimana cara kamu menyikapinya? , ceritakan alasannya!
'''
stop_list = ["atau","itu","menurut","mungkin","bahkan","jika"]

def stopword_removal (indikator):
  filtering = stop_list
  x = []
  data = []
  def my_func (x) :
    if x in filtering :
      return False
    else :
      return True

  fit = filter(my_func,indikator)
  for x in fit :
    data.append(x)
  return data

df['indikator_filter'] = df['Indikator_normalized'].apply(stopword_removal)
df['indikator_filter']
# Out:
# 0      [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                          [tidak, suka]
# 2      [biasanya, saya, akan, membagikan, hal, terseb...
# 3                               [orang, tertentu, doang]
# 4                         [orangorang, tertentu, sering]
#                              ...
# 120    [saya, memiliki, sebuah, tujuanrencana, saya, ...
# 121    [saya, saya, merupakan, tipe, orang, yang, ove...
# 122    [saya, jarang, upload, di, media, sosial, saya...
# 123    [saya, suka, dan, sering, bercerita, tentang, ...
# 124    [biasanya, hanya, menceritakan, kepada, orango...
# Name: indikator_filter, Length: 125, dtype: object

# %%
# Stemming

# !pip3 install Sastrawi
from sklearn.pipeline import Pipeline
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def stemming(indikator) :
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()

  do = []
  for w in indikator :
    dt = stemmer.stem(w)
    do.append(dt)

  data_clean = []
  d_clean = " ".join(do)
  print(d_clean)
  return d_clean

df['indikator_stemming'] = df['indikator_filter'].apply(stemming)
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# hanya bagi hal sebut kepada orangorang tertentukeluargasahabatteman dekat
# tidak suka
# biasa saya akan bagi hal sebut kepada orang dekat saya saat ini saya punya teman dekat dan biasa kami saling sharing kait rencana studi kami untuk juang ptn
# orang tentu doang
# orangorang tentu sering
# rencana yang tidak terlalu penting sering saya bagi ke siapa saja yang ingin tahu tetapi ada beberapa rencana yang sifat private dan saya pendam sendiri
# hanya kepada orang tentu dan jarang
# saya suka bagi informasi ilmu kepada siapa saja dengan senang hati
# orang orang tentu yang sudah saya percaya saya akan lebih buka kepada mereka sehingga sering bagi hal hal sebut kepada mereka
# saya tipe orang yang sering cerita di orangorang tentu jadi bisa dikatan sering sekali saya bagi saya milik buah rencana biasa saya bagi memberitahu hanya kepada orangorang tentu
# hanya kepada orangorang tentu saya tidak terlalu sering cerita kena rencana saya
# orang orang tentu dan tidak terlalu sering
# mungkin besar tidak dan kalaupun iya hanya kepada orang orang tentu saja yang benar benar sudah saya percaya
# hanya kepada orang tua saja dan teman yang sudah saya anggap dekat
# saya saya akan bagi hal hal sebut kepada orangorang tentu karena saya sendiri juga kurang suka umbar tuju hidup saya ke depan publik saya sendiri cerita kepada orangorang tentu masih mem mana yang bisa saya cerita dan tidak
# apabila saya milik rencana saya akan cerita namun hanya kepada orang yang kompeten orang yang dekat dengan saya agar saya dapat kritik dan saran agar saya dapat laku rencana sebut dengan lancar
# akan saya bagi dengan keluarga saja dan saya sangat jarang untuk bahas nya jadi jarang bagis saya untuk bagi nya
# tidak akan bagi hal sebut
# hanya orang orang tentu tidak terlalu sering karena saya bagi yang penting penting saja selain saya lebih suka untuk simpan sendiri
# saya sendiri cenderung bagi hanya kepada orang tentu seperti orang tuasepupu sahabat
# tidak hanya kepada orang tentu karena saya tujuanrencana rupa hal yang saya laku bukan orang lain yang laku biasa hal seperti tuju rencana banyak hanya orang tua saya sendiri bilang sering tidak juga lihat kondisi seperti apa
# saya suka bagi giat random saya di story sosmed
# hanya orangorang tentu karena saya lebih suka tunjuk hasil daripada proses saya karena tidak semua orang paham dengan kondisi saya
# kepada orang orang tentu
# hampir tidak pernah bagi kepada publik paling bagi ke teman dekat dan keluarga saja
# hanya ke orang yang dekat saya saja saya suka bagi cerita dengan teman saya di saat ngobrol
# kepada orangorang tentu tidak berapa sering
# hanya kepada orangorang tentu karena kita cerita harus percaya orang sebut
# saya jarang sekali bagi hal hal seperti kepada kerabat kalau tidak pepet
# saya kurang suka bagi hal sebut kepada orang umum karena saya private dan biar orang tahu hasil jangan proses
# saya milik rencana saya lebih baik simpan sendiri hanya kepada orang dekat saja
# saya akan bagi ke orang lain orang tentu nyaman dan semoodnya saya tetapi saya lebih tidak sering bagi
# hanya kepada orang tentu jarang bagi
# tidak pernah karena rupa privasi bagi saya
# saya sering bagi tuju dan rencana saya ke depan dengan ibu saya karena ibu saya selalu punya solusi untuk saya
# hanya orang orang tentu
# saya lebih untuk pendam rencana saya tetapi saya ragu dengan rencana sebut saya hanya bagi ke teman dan orang tua
# saya akan bagi ke publik bagi perlu saja tidak lebih
# kepada orang tentu saya bagi cerita cukup saja tidak oversharing karena jaman sekarang tidak ada yang bisa percaya kecuali diri sendiri
# hanya kepada orang orang tentu saya tidak terlalu sering untuk bagi
# saya selalu cerita kpd sahabat dekat saya apa masalah nya seperti saya sedang sedih dan senang
# hanya orang tentu saja karena saya ada rencana jangan di beritahu kepada orang awam bisa saja rencana sebut tidak jalan dengan lancar
# memang hal sebut buah hal kandung hal positif dan bisa contoh saya akan mengeshare untuk baik sama memang hal sebut negatif tidak penting saya kadang share tetapi cf
# saya bagi tujuanrencana kepada orang orang tentu dan saya tidak sering bagi tujuanrencana sebut
# biasa saya lebih sembunyi proses tuju rencana saya kepada publik pun di medsos
# bagi saya sendiri halhal sebut lebih baik bagi untuk orangorang tentu hal ini tuju untuk meminimalisir ketidaksukaan orang lain kepada saya saya pun sering bagi halhal rencana yang saya laku kepada orangorang dekat saya dengan tuju untuk motivasi mereka untuk laku suatu hal yang produktif
# iya saya suka bagi hal sebut seperti upload di wa atau instragam saya sering bagi supaya tuju manfaat bagi orang orang juga
# pilih saya pribadi hanya orang tentu saja seperti keluargasaudara karena penikiran saya hanya privat laku sharring hidup apa yang saya laku ke media sosial saya tidak suka laku karena buat seperti orang bodoh yang minta minta dengan buka donasi
# saya lebih suka pikir sendiri rencana sebut apabila ada orang yang tanya hal sebut maka saya jawab dengan syarat orang sebut golong dekat dengan saya
# di media sosial tetapi hanya untuk teman teman dekat
# saya lebih bagi cerita sebut kepada teman dekat saya tetapi kadangkadang juga pernah di sosmed hampir tiap hari si tetapi sesuai mood saja
# tidak pernah bagi
# saya jarang bagi tuju maupun rencana saya kepada orang umumpublik saya lebih bagi tuju dan rencana saya kepada orang tentu
# tidak
# saya hanya bagi hal sebut hanya kepada orang tentu dan saya tidak terlalu sering bagi
# saya akan bagi ke orang orang dekat saya
# saya sangat sering tunjuk ke banyak orang tentang goals dan impi saya baik di sosial media cara langsung
# saya akan bagi nya kepada orang tentu
# kalau rencana si private saja to my closest friends
# saya jarang bagi rencana saya
# saya cenderung suka bagi kepada orangorang tentu yang saya percaya
# lebih sering dikeep sendiri kalau ingin sharing biasa ngetwt di akun only me
# hanya kepada orangorang tentu tetapi jarang
# hanya di bagi kepada beberapa orang saja dan jarang bagi
# gantung dengan rencana sebut apabila saya meiliki rencana penting yang kait dengan akademik dan pribadi saya tidak pernah bagi namun untuk rencana seperti ide cerita ide lain yang sifat umum saya seringkali minta dapat orang sekitar saya
# tidak namun di tag lalu instagram saya akan bagi nya juga seperti rencana cosplay
# hanya pada orang orang tentu dan saya sering membagikanya hanya hal penting
# suka share halhal random saja di story ig tetapi akun yang khusus temen dekat kalau tujuanrencana biasa share di akun private twitter
# saya akan bagi kepada orang tentu saja
# saya biasa suka membagikanya ke sosial media saya teman saya dan saya sangat sering
# hanya beberapa orang bentuk yang saya percaya mereka akan harga rencana yang akan saya laku sering saya sangat percaya orang sebut
# gantung rencana
# saya tidak pernah suka bagi tuju rencana yang saya ingin kecuali apabila memang kait dengan kerja dan hal hal kecil lai apabila tuju rencana yang akan saya capai besar saya cenderung menyimpanya sendiri
# saya keep rencana saya sampai rencana sebut capai tuju lalu saya cerita part bagaimana saya bisa sampai di titik tetapi hanya kepada orang yang saya anggap dekat dengan saya
# untuk hal yang sifat rencana tuju ada kala saya harus keep dengan tidak cerita ke orang lain namun rencana hanya dar tuju universitas dan lain bagai saya tidak rasa berat bila bagi nya dengan orang lain
# saya milik buah rencana untuk masa depan saya saya akan simpan sendiri tanpa tunjuk ke siapa saya akan tunjuk hasil saja saya tunjuk kepada keluarga dan teman dekat saya
# saya tidak suka bagi buah tujuanrencana kepada orang lain saya tujuanrencana sebut tidak ada guna untuk orang lain kecuali diri saya sendiri
# hanya orangorang tentu seperti pacar dan teman tetapi tidak sering
# hanya orang dekat saja yang saya bagi rencana depan kalau untuk di bagi ke orang umum nanti akan jadi bahan omong rencana sebut tidak di jalan dan saya lebih banyak bagi kepada diri sendiri dan jarang bagi kepada orang lain
# orang tentu sih mas biasa yang saya percaya saja karena kalau semua orang tahu potensi rencana untuk gagal bisa tinggi karena pasti ada saja yang tidak suka dan iri dan saya pribadi lebih suka keep sendiri sih takut bikin orang lain harap tinggi juga malah ngecewain nanti jadi mending saya sendiri yang kecewa orang lain jangan
# tidak suka bagi rencana saya untuk orang lain
# saya hanya akan bagi kepada beberapa orang tentu saja dan seperti tidak sering laku
# hanya kepada orang orang tentu dan yang dekat saja sering hanya ingin cerita
# rencana saya sifat umum maka akan bagi ke publik namun dan rencana sifat pribadi bisa jadi lahan untung saya akan bagi kepada orang orang tentu untuk sering tidak jawab nya adalah tidak cukup
# biasa saya hanya lihat di sosmed ke teman dekat
# kepada orang orang tentu hanya beberapa kali
# saya akan bagi hal sebut ke orangorang tentu saja dan pada momen tentu saja
# lebih suka untuk simpan sendiri karena tujuanrencana milik proses yang hanya tahu oleh diri sendiri
# saya tidak akan memberitahu siapa kandung masalah pribadi tentang masa depan saya akan konsultasi dengan teman dekat dan orang tua
# saya akan bagi nya kepada orang orang tentu sajamungkin kalau ingat sering cerita
# saya hanya bagi kepada keluarga saja karena saya orang lain tidak perlu tahu tentang apa yang saya rencana
# saya milik tujuanrencana saya lebih sering cerita kepada teman orang dekat saja
# iya saya akan bagi tetapi jarang
# saya hanya bagi kepada orang orang tentu tiap kali saya pikir rencana tuju sebut maka daya akan bagi ke teman yang saya percaya dekat dengan saya
# terkadang saya bagi ke sosial media namun lebih sering kepada orang tentu saja seperti sahabat dekat saya
# saya bukan tipe orang yang suka bagi tuju rencana kepada orang lain utama di media sosial
# hanya orangorang tentu saja saya tidak sering bagi karena jarang keluar dari rumah
# saya punya tujuanrencana saya suka bagi hal sebut kepada orang orang tentu seperti sahabat sayasaudara saya dan saya bagi tiap saya punya tujuanrencana untuk depan karena saya sangat sangat butuh support dan saran orang orang tentu
# bagi hal sebut kepada publik sangat sering
# hanya kepada orang tentu
# gantung apa yang saya mau tunjuk
# cerita kepada orangorang tentu seperti orangtua dan saudara sering kali saya bercrita dengan mereka dan minta saran motivasi pada mereka
# lebih suka bagi hal kepada orang tentu namun saya tidak begitu sering bagi rencana saya kepada orang lain kecuali rencana kecilkecilan
# lebih ke bagi ke orang tentu yang dekat saja
# tidak suka bagi ke publik lebih suka untuk diam
# iyaa saya lebih suka untuk bagi kepada orang
# gantung rencana apa yang tuju kadang saya suka bagi hal sebut ke publik kadang juga bisa untuk orang dekat saja
# hanya orang tentu tidak memberitahukannya karena tidak semua rencana saya dapat saya cerita dengan nyaman ke orang dekat
# saya biasa kalau ada tuju rencana saya selalu bagi kepada orang tentu saja
# hanya ke orang dekat yang saya sudah kenal lama dan saya percayasering
# kepada orang tentu saja tidak terlalu sering
# saya biasa bagi cerita tentang tuju dan rencana masa depan dengan orangorang tertentuseperti teman dekat saya dan orang tua saya
# saya akan bagi kepada orangorang tentu sering sekali kalau suasana hati saya lagi senang namun lebih pilih hanya saya yang tahu apabila saya ambisi
# saya lebih suka untuk bagi hanya kepada orang orang tentu dan saya juga jarang sekali bagi ke orang orang yang tidak saya kenal maupun media sosial
# kepada orang tentu berapa sering gantung karena saya lebih pilih untuk di liar arah yang positif
# saya lebih suka cerita kepada orang yang saya percaya hanya di orang orang tentu saja tetapi tidak semua saya cerita
# apabila saya punya rencana akan masa depan saya saya cenderung pendam rencana sebut untuk diri saya sendiri saya cukup jarang cerita rencana saya kecuali ke orangorang yang benarbenar dekat walaupun begitu saya tidak terlalu cerita cara sering dan detail
# saya cenderung hanya bagi kepada beberapa orang saja hal ini tidak terlalu sering saya laku karena saya cenderung lebih senang laku rencana sesuatu cara diam diam dan baru bagi ketika sudah laku rencana sebut
# saya hanya bagi hal sebut kepada orang tentu dan dekat saya tidak terlalu sering karena saya tahu bahwa hidup saya perlu privasi pribadi
# saya pribadi lebih suka simpan sendiri saya bagi kepada orang tentu saja
# saya milik buah tujuanrencana saya lebih suka untuk tidak bagi namun tarkadang tanpa sadar saya cerita dengan orang lain yang sudah dekat dengan saya
# saya saya rupa tipe orang yang oversharing jadi lebih sering bagi tuju rencana saya depan karena saya pikir bincang kena tuju dan rencana depan rupa hal positif yang dapat kembang semangat yang lebih
# saya jarang upload di media sosial saya kalau upload di media sosial gantung mood saja
# saya suka dan sering cerita tentang diri saya di depan banyak orang karena saya rasa neng jadi pusat perhati
# biasa hanya cerita kepada orangorang yang tanya saja terkadang saja

# %%
#tokenize data stemming

 #NLTK word tokenize
def stemmed_tokenizing(indikator) :
  return word_tokenize(indikator)

df['indikator_stemmed_tokens'] = df['indikator_stemming'].apply(stemmed_tokenizing)

# %%
pd.DataFrame(df[['Indikator_normalized', 'indikator_filter', 'indikator_stemmed_tokens']])
# Out:
#                                   Indikator_normalized  \
# 0    [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                        [tidak, suka]
# 2    [biasanya, saya, akan, membagikan, hal, terseb...
# 3                             [orang, tertentu, doang]
# 4                       [orangorang, tertentu, sering]
# ..                                                 ...
# 120  [jika, saya, memiliki, sebuah, tujuanrencana, ...
# 121  [menurut, saya, saya, merupakan, tipe, orang, ...
# 122  [saya, jarang, upload, di, media, sosial, saya...
# 123  [saya, suka, dan, sering, bercerita, tentang, ...
# 124  [biasanya, hanya, menceritakan, kepada, orango...
#
#                                       indikator_filter  \
# 0    [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                        [tidak, suka]
# 2    [biasanya, saya, akan, membagikan, hal, terseb...
# 3                             [orang, tertentu, doang]
# 4                       [orangorang, tertentu, sering]
# ..                                                 ...
# 120  [saya, memiliki, sebuah, tujuanrencana, saya, ...
# 121  [saya, saya, merupakan, tipe, orang, yang, ove...
# 122  [saya, jarang, upload, di, media, sosial, saya...
# 123  [saya, suka, dan, sering, bercerita, tentang, ...
# 124  [biasanya, hanya, menceritakan, kepada, orango...
#
#                               indikator_stemmed_tokens
# 0    [hanya, bagi, hal, sebut, kepada, orangorang, ...
# 1                                        [tidak, suka]
# 2    [biasa, saya, akan, bagi, hal, sebut, kepada, ...
# 3                                [orang, tentu, doang]
# 4                          [orangorang, tentu, sering]
# ..                                                 ...
# 120  [saya, milik, buah, tujuanrencana, saya, lebih...
# 121  [saya, saya, rupa, tipe, orang, yang, overshar...
# 122  [saya, jarang, upload, di, media, sosial, saya...
# 123  [saya, suka, dan, sering, cerita, tentang, dir...
# 124  [biasa, hanya, cerita, kepada, orangorang, yan...
#
# [125 rows x 3 columns]

# %%
df.head()
# Out:
#                                            Indikator Tipe  \
# 0  hanya membagikan hal tersebut kepada orang-ora...    I
# 1                                         tidak suka    I
# 2  biasanya saya akan membagikan hal tersebut kep...    I
# 3                               orang tertentu doang    I
# 4                       orang-orang tertentu. sering    I
#
#                                      Indikator_clean  \
# 0  hanya membagikan hal tersebut kepada orangoran...
# 1                                         tidak suka
# 2  biasanya saya akan membagikan hal tersebut kep...
# 3                               orang tertentu doang
# 4                         orangorang tertentu sering
#
#                                     Indikator_tokens  \
# 0  [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                      [tidak, suka]
# 2  [biasanya, saya, akan, membagikan, hal, terseb...
# 3                           [orang, tertentu, doang]
# 4                     [orangorang, tertentu, sering]
#
#                                 Indikator_normalized  \
# 0  [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                      [tidak, suka]
# 2  [biasanya, saya, akan, membagikan, hal, terseb...
# 3                           [orang, tertentu, doang]
# 4                     [orangorang, tertentu, sering]
#
#                                     indikator_filter  \
# 0  [hanya, membagikan, hal, tersebut, kepada, ora...
# 1                                      [tidak, suka]
# 2  [biasanya, saya, akan, membagikan, hal, terseb...
# 3                           [orang, tertentu, doang]
# 4                     [orangorang, tertentu, sering]
#
#                                   indikator_stemming  \
# 0  hanya bagi hal sebut kepada orangorang tertent...
# 1                                         tidak suka
# 2  biasa saya akan bagi hal sebut kepada orang de...
# 3                                  orang tentu doang
# 4                            orangorang tentu sering
#
#                             indikator_stemmed_tokens
# 0  [hanya, bagi, hal, sebut, kepada, orangorang, ...
# 1                                      [tidak, suka]
# 2  [biasa, saya, akan, bagi, hal, sebut, kepada, ...
# 3                              [orang, tentu, doang]
# 4                        [orangorang, tentu, sering]

# %% [markdown]
# # Feature extraction

# %%
# Feature extraction packages
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
data_clean = df.astype({'Tipe' : 'category'})
data_clean = df.astype({'indikator_stemmed_tokens' : 'string'})
data_clean.dtypes
# Out:
# Indikator                           object
# Tipe                                object
# Indikator_clean                     object
# Indikator_tokens                    object
# Indikator_normalized                object
# indikator_filter                    object
# indikator_stemming                  object
# indikator_stemmed_tokens    string[python]
# dtype: object

# %%
#  memeriksa missing value
df.isnull().any()
# Out:
# Indikator                   False
# Tipe                        False
# Indikator_clean             False
# Indikator_tokens            False
# Indikator_normalized        False
# indikator_filter            False
# indikator_stemming          False
# indikator_stemmed_tokens    False
# dtype: bool

# %%
# Missing value handling

for idx in data_clean.index:
 if(len(data_clean["indikator_stemming"][idx]) == 0):
  data_clean = data_clean.drop(index=idx)

# %%
# Inisialisasi objek TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Melakukan pembobotan TF-IDF pada kolom "indikator"
X = tfidf_vectorizer.fit_transform(data_clean['indikator_stemmed_tokens'])

# %%
len(data_clean)
# Out:
# 125

# %%
# encoding label
enc = LabelEncoder()
data_clean['type of encoding'] = enc.fit_transform(data_clean['Tipe'])

y = data_clean['type of encoding']

# %% [markdown]
# # Splitting Data

# %%
# Splitting data package
from sklearn.model_selection import train_test_split

# %%
if X.shape[0] != y.shape[0]:
  print("X and y rows are mismatched, check dataset again")

# %%
pd.DataFrame(X,y)
# Out:
#                                                                   0
# type of encoding
# 1                   (0, 61)\t0.30151950238580894\n  (0, 307)\t0....
# 1                   (0, 291)\t0.7804846341162808\n  (0, 311)\t0....
# 1                   (0, 231)\t0.24374172172916267\n  (0, 110)\t0...
# 1                   (0, 70)\t0.9121187601519826\n  (0, 304)\t0.3...
# 1                   (0, 271)\t0.5352427620205906\n  (0, 304)\t0....
# ...                                                             ...
# 1                   (0, 243)\t0.3205965954228489\n  (0, 300)\t0....
# 0                   (0, 264)\t0.2267689235928615\n  (0, 131)\t0....
# 1                   (0, 74)\t0.22590217023125783\n  (0, 186)\t0....
# 0                   (0, 218)\t0.3387334103449807\n  (0, 235)\t0....
# 1                   (0, 305)\t0.47108140861967585\n  (0, 299)\t0...
#
# [125 rows x 1 columns]

# %%
# Splitting data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=12, shuffle=True)
print ((X_train.shape),(y_train.shape),(X_test.shape),(y_test.shape))
# Out:
# (93, 333) (93,) (32, 333) (32,)

# %% [markdown]
# # Train Model & Selecting Model

# %%
#Models
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance

#Metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score, multilabel_confusion_matrix, confusion_matrix
from sklearn.metrics import classification_report

# Ignore noise warning
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.pipeline import make_pipeline

accuracies = {

}

f1_scores = {

}

#Random Forest
random_forest = RandomForestClassifier()#n_estimators=100, random_state = 7)
# fit the model
random_forest.fit(X_train, y_train)
# train score
train_score = random_forest.score(X_train, y_train)
# test score
test_score = random_forest.score(X_test,y_test)
# predict
Y_pred = random_forest.predict(X_test)
predictions = [round(value) for value in Y_pred]

# Metric evaluation
#cv scores
cv_scores = cross_val_score(random_forest, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['Random Forest'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# print("Accuracy: %.2f%%" % (predict_score * 100.0))

# %%
random_forest.score(X_train,y_train),random_forest.score(X_test, y_test)
# Out:
# (1.0, 0.8125)

# %%
#XG boost Classifier
xgb = XGBClassifier()
xgb.fit(X_train,y_train)

train_score = xgb.score(X_train, y_train)
test_score = xgb.score(X_test,y_test)
Y_pred = xgb.predict(X_test)
predictions = [round(value) for value in Y_pred]

# Metric evaluation
#cv scores
cv_scores = cross_val_score(xgb, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['XG Boost'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# %%
xgb.score(X_train,y_train),xgb.score(X_test, y_test)
# Out:
# (1.0, 0.75)

# %%
#Gradient Descent
sgd = SGDClassifier()
sgd.fit(X_train, y_train)

train_score = sgd.score(X_train, y_train)
test_score = sgd.score(X_test,y_test)
Y_pred = sgd.predict(X_test)
predictions = [round(value) for value in Y_pred]

#Metric evaluation
#cv scores
cv_scores = cross_val_score(sgd, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['SGD'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# %%
sgd.score(X_train,y_train),sgd.score(X_test, y_test)
# Out:
# (1.0, 0.75)

# %%
# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

train_score = logreg.score(X_train, y_train)
test_score = logreg.score(X_test,y_test)
Y_pred = logreg.predict(X_test)
predictions = [round(value) for value in Y_pred]

# Metric evaluation
#cv scores
cv_scores = cross_val_score(logreg, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['Logreg'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# %%
logreg.score(X_train,y_train),logreg.score(X_test, y_test)
# Out:
# (0.7956989247311828, 0.8125)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

train_score = knn.score(X_train, y_train)
test_score = knn.score(X_test,y_test)
Y_Pred = knn.predict(X_test)
predictions = [round(value) for value in Y_pred]

# Metric evaluation
#cv scores
cv_scores = cross_val_score(knn, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['KNN'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# %%
knn.score(X_train,y_train),knn.score(X_test, y_test)
# Out:
# (0.8387096774193549, 0.78125)

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)

train_score = svm.score(X_train, y_train)
test_score = svm.score(X_test,y_test)
Y_pred = svm.predict(X_test)

# Metric evaluation
# cv scores
cv_scores = cross_val_score(svm, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['SVM'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# %%
svm.score(X_train,y_train),svm.score(X_test, y_test)
# Out:
# (0.946236559139785, 0.8125)

# %%
# Naive bayes
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

mnb = MultinomialNB().fit(X_train, y_train)

# evaluate score
train_score = mnb.score(X_train, y_train)

test_score = mnb.score(X_test,y_test)

Y_pred = svm.predict(X_test)
predictions = [round(value) for value in Y_pred]

# Metric evaluation
#cv scores
cv_scores = cross_val_score(mnb, X, y, cv=4, scoring='f1_macro').mean()
# evaluate predictions use f1 score
predict_score = f1_score(y_test, predictions)

# Append data
f1_scores['MNB'] = {'CV f1-Scores':round((cv_scores * 100),2)}#, 'Predict f1 Scores': round((predict_score * 100.0),2)}

# %%
mnb.score(X_train,y_train),xgb.score(X_test, y_test)
# Out:
# (0.7956989247311828, 0.75)

# %%
pd.DataFrame.from_dict(f1_scores, orient='index', columns=['CV f1-Scores']).sort_values(by='CV f1-Scores',ascending=False)
# Out:
#                CV f1-Scores
# SGD                   67.10
# XG Boost              60.14
# KNN                   51.03
# Logreg                44.45
# MNB                   44.45
# SVM                   44.45
# Random Forest         44.20

# %%
y_test.value_counts()
# Out:
# type of encoding
# 1    26
# 0     6
# Name: count, dtype: int64

# %%
pd.DataFrame(data_clean[['Tipe','type of encoding']])
# Out:
#     Tipe  type of encoding
# 0      I                 1
# 1      I                 1
# 2      I                 1
# 3      I                 1
# 4      I                 1
# ..   ...               ...
# 120    I                 1
# 121    E                 0
# 122    I                 1
# 123    E                 0
# 124    I                 1
#
# [125 rows x 2 columns]

# %% [markdown]
# # Model Improvement

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # **Gradient Descent Hyperparameter Tuning**

# %%
# define params for tuning Naive Bayes
parameter = {
    "loss" : ['hinge','log_loss','modified_huber','perceptron','squared_error','squared_hinge','huber','psilon_insensitive','squared_psilon_insensitive'],
    "penalty" : ['l2','l1','elasticnet',None],
    "alpha" : [0.0001, 0.001, 0.01, 0.1, 1.0],
    "max_iter" : np.arange(0, 1000, 100),
}

sgd_improve = SGDClassifier()
sgd_improve_model = GridSearchCV(sgd_improve, parameter, cv=4, n_jobs=-1, verbose=1, scoring='f1_macro')
sgd_improve_model.fit(X, y)

# Menampilkan hyperparameter terbaik dan skor terbaik
print("Hyperparameter terbaik:", sgd_improve_model.best_params_)
print("Skor terbaik:", sgd_improve_model.best_score_)
# Out:
# Fitting 4 folds for each of 1800 candidates, totalling 7200 fits
# Hyperparameter terbaik: {'alpha': 0.1, 'loss': 'squared_hinge', 'max_iter': 600, 'penalty': None}
# Skor terbaik: 0.72067262751225

# %%
sgd = SGDClassifier(alpha =  0.01, loss = 'perceptron', max_iter = 800, penalty = None)
sgd.fit(X_train,y_train)
# Out:
# SGDClassifier(alpha=0.01, loss='perceptron', max_iter=800, penalty=None)

# %%
# get a prediction
y_hat = sgd.predict(X_train)
y_sgd = sgd.predict(X_test)

# %%
# from sklearn.metrics as metrics import accuracy_score,precision_score, recall_score, f1_score
import sklearn.metrics as metrics

print('Training set accuracy: ', metrics.accuracy_score(y_train, y_hat)*100)
print('Test set accuracy: ',metrics.accuracy_score(y_test, y_sgd) * 100)
print('Test set f1-score: ',metrics.f1_score(y_test, y_sgd) * 100)
print('Test set precision: ',metrics.precision_score(y_test, y_sgd) * 100)
print('Test set recall: ',metrics.recall_score(y_test, y_sgd) * 100)
# Out:
# Training set accuracy:  100.0
# Test set accuracy:  80.64516129032258
# Test set f1-score:  88.8888888888889
# Test set precision:  82.75862068965517
# Test set recall:  96.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_sgd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25         6
#            1       0.83      0.96      0.89        25
#
#     accuracy                           0.81        31
#    macro avg       0.66      0.56      0.57        31
# weighted avg       0.76      0.81      0.77        31

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Hitung confusion matrix
conf_matrix = confusion_matrix(y_test, y_sgd)

# Mendapatkan nilai True Positive, True Negative, False Positive, False Negative dari confusion matrix
TN = conf_matrix[0][0]
FP = conf_matrix[1][0]
FN = conf_matrix[0][1]
TP = conf_matrix[1][1]

# Menampilkan confusion matrix sebagai heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('SVM Confusion Matrix')
plt.show()

# Menampilkan nilai True Positive, True Negative, False Positive, False Negative
print("True Positives:", TP)
print("True Negatives:", TN)
print("False Positives:", FP)
print("False Negatives:", FN)
# Out:
# True Positives: 24
# True Negatives: 1
# False Positives: 1
# False Negatives: 5

# %% [markdown]
# # SGD SMOTE

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE()

X_sm, y_sm = sm.fit_resample(X, y)

# %%
# define params for tuning Naive Bayes
parameter = {
    "loss" : ['hinge','log_loss','modified_huber','perceptron','squared_error','squared_hinge','huber','psilon_insensitive','squared_psilon_insensitive'],
    "penalty" : ['l2','l1','elasticnet',None],
    "alpha" : [0.0001, 0.001, 0.01, 0.1, 1.0],
    "max_iter" : np.arange(0, 1000, 100),
}

sgd_improve = SGDClassifier()
sgd_improve_model = GridSearchCV(sgd_improve, parameter, cv=4, n_jobs=-1, verbose=1, scoring='f1_macro')
sgd_improve_model.fit(X_sm, y_sm)

# Menampilkan hyperparameter terbaik dan skor terbaik
print("Hyperparameter terbaik:", sgd_improve_model.best_params_)
print("Skor terbaik:", sgd_improve_model.best_score_)
# Out:
# Fitting 4 folds for each of 1800 candidates, totalling 7200 fits
# Hyperparameter terbaik: {'alpha': 0.0001, 'loss': 'perceptron', 'max_iter': 200, 'penalty': 'l1'}
# Skor terbaik: 0.9548856073943026

# %%
knn = KNeighborsClassifier(leaf_size=1, metric='minkowski', n_neighbors=5, p=2, weights='uniform')
knn.fit(X_train_sm, y_train_sm)
# Out:
# KNeighborsClassifier(leaf_size=1)

# %%
# get a prediction
y_hat = knn.predict(X_train_sm)
y_knn = knn.predict(X_test)

# %%
# from sklearn.metrics as metrics import accuracy_score,precision_score, recall_score, f1_score
import sklearn.metrics as metrics

print('Training set accuracy: ', metrics.accuracy_score(y_train_sm, y_hat)*100)
print('Test set accuracy: ',metrics.accuracy_score(y_test, y_knn) * 100)
print('Test set f1-score: ',metrics.f1_score(y_test, y_knn) * 100)
print('Test set precision: ',metrics.precision_score(y_test, y_knn) * 100)
print('Test set recall: ',metrics.recall_score(y_test, y_knn) * 100)
# Out:
# Training set accuracy:  85.48387096774194
# Test set accuracy:  65.625
# Test set f1-score:  70.27027027027026
# Test set precision:  81.25
# Test set recall:  61.904761904761905

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.73      0.59        11
#            1       0.81      0.62      0.70        21
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.67      0.65        32
# weighted avg       0.71      0.66      0.66        32

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Hitung confusion matrix
conf_matrix = confusion_matrix(y_test, y_knn)

# Mendapatkan nilai True Positive, True Negative, False Positive, False Negative dari confusion matrix
TN = conf_matrix[0][0]
FP = conf_matrix[1][0]
FN = conf_matrix[0][1]
TP = conf_matrix[1][1]

# Menampilkan confusion matrix sebagai heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('SVM Confusion Matrix')
plt.show()

# Menampilkan nilai True Positive, True Negative, False Positive, False Negative
print("True Positives:", TP)
print("True Negatives:", TN)
print("False Positives:", FP)
print("False Negatives:", FN)
# Out:
# True Positives: 13
# True Negatives: 8
# False Positives: 8
# False Negatives: 3

# %% [markdown]
# # SGD ADS

# %%
from imblearn.over_sampling import ADASYN

ads = ADASYN()

X_ads, y_ads = ads.fit_resample(X, y)

# %%
# define params for tuning Naive Bayes
parameter = {
    "loss" : ['hinge','log_loss','modified_huber','perceptron','squared_error','squared_hinge','huber','psilon_insensitive','squared_psilon_insensitive'],
    "penalty" : ['l2','l1','elasticnet',None],
    "alpha" : [0.0001, 0.001, 0.01, 0.1, 1.0],
    "max_iter" : np.arange(0, 1000, 100),
}

sgd_improve = SGDClassifier()
sgd_improve_model = GridSearchCV(sgd_improve, parameter, cv=4, n_jobs=-1, verbose=1, scoring='f1_macro')
sgd_improve_model.fit(X_ads, y_ads)

# Menampilkan hyperparameter terbaik dan skor terbaik
print("Hyperparameter terbaik:", sgd_improve_model.best_params_)
print("Skor terbaik:", sgd_improve_model.best_score_)
# Out:
# Fitting 4 folds for each of 1800 candidates, totalling 7200 fits
# Hyperparameter terbaik: {'alpha': 0.01, 'loss': 'perceptron', 'max_iter': 400, 'penalty': 'l2'}
# Skor terbaik: 0.9643047160335706

# %% [markdown]
# # SGD TL

# %%
from imblearn.under_sampling import TomekLinks

tl = TomekLinks()

X_tl, y_tl = tl.fit_resample(X, y)

# %%
# define params for tuning Naive Bayes
parameter = {
    "loss" : ['hinge','log_loss','modified_huber','perceptron','squared_error','squared_hinge','huber','psilon_insensitive','squared_psilon_insensitive'],
    "penalty" : ['l2','l1','elasticnet',None],
    "alpha" : [0.0001, 0.001, 0.01, 0.1, 1.0],
    "max_iter" : np.arange(0, 1000, 100),
}

sgd_improve = SGDClassifier()
sgd_improve_model = GridSearchCV(sgd_improve, parameter, cv=4, n_jobs=-1, verbose=1, scoring='f1_macro')
sgd_improve_model.fit(X_tl, y_tl)

# Menampilkan hyperparameter terbaik dan skor terbaik
print("Hyperparameter terbaik:", sgd_improve_model.best_params_)
print("Skor terbaik:", sgd_improve_model.best_score_)
# Out:
# Fitting 4 folds for each of 1800 candidates, totalling 7200 fits
# Hyperparameter terbaik: {'alpha': 0.0001, 'loss': 'squared_hinge', 'max_iter': 600, 'penalty': None}
# Skor terbaik: 0.7776571082978645

# %% [markdown]
# # SGD RUS

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()

X_rus, y_rus = rus.fit_resample(X, y)

# %%
# define params for tuning Naive Bayes
parameter = {
    "loss" : ['hinge','log_loss','modified_huber','perceptron','squared_error','squared_hinge','huber','psilon_insensitive','squared_psilon_insensitive'],
    "penalty" : ['l2','l1','elasticnet',None],
    "alpha" : [0.0001, 0.001, 0.01, 0.1, 1.0],
    "max_iter" : np.arange(0, 1000, 100),
}

sgd_improve = SGDClassifier()
sgd_improve_model = GridSearchCV(sgd_improve, parameter, cv=4, n_jobs=-1, verbose=1, scoring='f1_macro')
sgd_improve_model.fit(X_rus, y_rus)

# Menampilkan hyperparameter terbaik dan skor terbaik
print("Hyperparameter terbaik:", sgd_improve_model.best_params_)
print("Skor terbaik:", sgd_improve_model.best_score_)
# Out:
# Fitting 4 folds for each of 1800 candidates, totalling 7200 fits
# Hyperparameter terbaik: {'alpha': 0.0001, 'loss': 'squared_hinge', 'max_iter': 700, 'penalty': 'l2'}
# Skor terbaik: 0.8188644688644688

# %% [markdown]
# # Predict Testing

# %%
list_indikator = np.array(data_clean['indikator_stemmed_tokens'])
list_tipe = np.array(data_clean['type of encoding'])

# %%
cntizer = CountVectorizer(analyzer="word",max_features=1000, min_df = 0.01)
X_cnt = cntizer.fit_transform(list_indikator)

tfizer = TfidfTransformer()
X_tfidf =  tfizer.fit_transform(X_cnt).toarray()

# %%
# Posts in tf-idf representation
X = X_tfidf

# %%
X.shape
# Out:
# (126, 185)

# %%
'''
Dataset baru
'''
# user_input = "saya akan ikut dengannya,karna tugas bisa dikerjakan besok paginya" #P
user_input = "menolak nya, karena harus segera dikumpulkan " #J
# user_input = "Mengerjakan terlebih dahulu lalu mengabari teman bahwa saya akan menyusul " #J
# user_input = "mungkin sy akan mengerjakan tugas sebelum / setelah bertemu dgn tmn" #P
# user_input = "mengerjakan terlebih dahulu lalu baru pergi bermain " #J

my_X_cnt = cntizer.transform(np.array([user_input]))

my_X_tfidf =  tfizer.transform(my_X_cnt).toarray()

# %%
result = []

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=12)
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

model = LogisticRegression(C = 0.001, class_weight = 'balanced', penalty = 'l2', solver = 'liblinear')
# model.fit(X_train,y_train)
model.fit(X_train_sm, y_train_sm)

y_pred = model.predict(my_X_tfidf)
result.append(y_pred[0])

# %%
if result == [0] :
  result_output = 'J'
else :
  result_output = 'P'

print(user_input)
print("The result is : ", result_output)
# Out:
# menolak nya, karena harus segera dikumpulkan
# The result is :  J

# %%
y_test.value_counts()

# %%
data_clean['Tipe'].value_counts()

# %% [markdown]
# # Saving model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE

X = joblib.load('X_T3.sav')
y = joblib.load('y_T3.sav')

cntizer = CountVectorizer(analyzer="word",max_features=1000, min_df = 0.01)
X_cnt = cntizer.fit_transform(X)

tfizer = TfidfTransformer()
X_tfidf =  tfizer.fit_transform(X_cnt).toarray()
X = X_tfidf

'''
Dataset Baru
'''
# user_input = "saya akan ikut dengannya,karna tugas bisa dikerjakan besok paginya" #P
user_input = "menolak nya, karena harus segera dikumpulkan " #J
# user_input = "Mengerjakan terlebih dahulu lalu mengabari teman bahwa saya akan menyusul " #J
# user_input = "mungkin sy akan mengerjakan tugas sebelum / setelah bertemu dgn tmn" #P
# user_input = "mengerjakan terlebih dahulu lalu baru pergi bermain " #J

my_X_cnt = cntizer.transform(np.array([user_input]))

my_X_tfidf =  tfizer.transform(my_X_cnt).toarray()

result = []

sm = SMOTE()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=12)
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

model = LogisticRegression(C = 0.001, class_weight = 'balanced', penalty = 'l2', solver = 'liblinear')
model.fit(X_train_sm, y_train_sm)

joblib.dump(model,'clf_T3.sav')

y_pred = model.predict(my_X_tfidf)
result.append(y_pred[0])

if result == [0] :
  result_output = 'J'
else :
  result_output = 'P'

print(user_input)
print("The result is : ", result_output)
# Out:
# menolak nya, karena harus segera dikumpulkan
# The result is :  J

# %% [markdown]
# # Load Model

# %%
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from imblearn.under_sampling import RandomUnderSampler
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np

X = joblib.load('X_T3.sav')
y = joblib.load('y_T3.sav')

cntizer = CountVectorizer(analyzer="word",max_features=1000, min_df = 0.01)
X_cnt = cntizer.fit_transform(X)

tfizer = TfidfTransformer()
X_tfidf =  tfizer.fit_transform(X_cnt).toarray()
X = X_tfidf

'''
dataset Baru
'''
# user_input = "saya akan ikut dengannya,karna tugas bisa dikerjakan besok paginya" #P
# user_input = "menolak nya, karena harus segera dikumpulkan " #J
# user_input = "Mengerjakan terlebih dahulu lalu mengabari teman bahwa saya akan menyusul " #J
# user_input = "mungkin sy akan mengerjakan tugas sebelum / setelah bertemu dgn tmn" #P
# user_input = "mengerjakan terlebih dahulu lalu baru pergi bermain " #J
# user_input = "Saya akan mengatakan bahwasannya ingin menyelesaikan PR saya terlebih dahulu, dan akan menyusul apabila sudah selesai mengerjakannya." #J
# user_input = "Saya akan menyelesaikan terlebih dahulu tugas saya lalu menerima ajakan teman saya.. walau pertemuannya diundur beberapa jam." #J
# user_input = "Jika saya terganggu, saya akan minta maaf dan meminta waktu kepada dia agar saya bisa menyelesaikan tugas saya" #J
# user_input = "Saya akan menolaknya,karena ada tugas yang harus saya selesaikan hari itu juga" #J
# user_input = "Saya akan menolaknya dengan halus ataupun jika dia memaksa kemungkinan saya akan membawa PR saya di tempat tersebut lalu saya akan mengerjakan pr saya disana sembari mengobrol agar tidak terlalu suntuk mengerjakannya sendiri" #P

#P = 7 || N = 3

my_X_cnt = cntizer.transform(np.array([user_input]))

my_X_tfidf =  tfizer.transform(my_X_cnt).toarray()

result = []
model = joblib.load('clf_T3.sav')
y_pred = model.predict(my_X_tfidf)
result.append(y_pred[0])

if result == [0] :
  result_output = 'J'
else :
  result_output = 'P'

print(user_input)
print("The result is : ", result_output)
# Out:
# Saya akan menolaknya dengan halus ataupun jika dia memaksa kemungkinan saya akan membawa PR saya di tempat tersebut lalu saya akan mengerjakan pr saya disana sembari mengobrol agar tidak terlalu suntuk mengerjakannya sendiri
# The result is :  J

# %% [markdown]
# # Saving prepro

# %%
# diimport dulu terrr semua depedencies nya terr
import pandas as pd
import numpy as np
from numpy import asarray
from numpy import savetxt
from numpy import loadtxt
import pickle as pkl
# prepro depedencies
import re
import itertools
import string
import collections
from collections import Counter
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
# !pip3 install Sastrawi
from sklearn.pipeline import Pipeline
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# data cleansing
from IPython.utils import text
import string
import re #regex library
# Import word_tokennize & FreqDist from NLTK
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
# Feature extraction packages
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
# model algorithm
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN

# # load data
# data = pd.read_csv('A3.csv')

# # preprocessing the data -> cleanse the data & convert feature dtype as a vector/numbers yagesya biar bisa dipahami sama mesinnya brok.
# data['Indikator'] = data['Indikator'].str.lower()
# pd.DataFrame(data['Indikator'])

# def data_clean(indikator) :
#   #remove tab. new line, and back slice
#   indikator = indikator.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
#   #remove non ASCII (emoticon,dll)
#   indikator = indikator.encode('ascii', 'replace').decode('ascii')
#   #remove mention, link, hashtag
#   indikator = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", indikator).split())
#   #remove number
#   indikator = re.sub(r"\d+", "", indikator)
#   #remove punctuation
#   indikator = indikator.translate(str.maketrans("","",string.punctuation))
#   #remove whitespace leading & trailing
#   indikator =  indikator.strip()
#   #remove multiple white spacew into single white space
#   indikator = re.sub('\s+', ' ', indikator)
#   #remove single char
#   indikator = re.sub(r"\b[a-zA-Z]\b", "", indikator)

#   return indikator
# data['Indikator_clean'] = data['Indikator'].apply(data_clean)
#   #NLTK word tokenize
# def word_tokenize_wrapper(indikator) :
#   return word_tokenize(indikator)

# data['Indikator_tokens'] = data['Indikator_clean'].apply(word_tokenize_wrapper)

# normalizad_word = pd.read_csv("normalisasi1.csv")

# normalizad_word_dict = {}

# for index, row in normalizad_word.iterrows():
#     if row[0] not in normalizad_word_dict:
#         normalizad_word_dict[row[0]] = row[1]

# def normalized_term(document):
#     return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# data['Indikator_normalized'] = data['Indikator_tokens'].apply(normalized_term)

# # filtering
# import nltk
# from nltk.corpus import stopwords
# nltk.download('stopwords')


# def stopword_removal (indikator):
#   filtering = stopwords.words('indonesian','english')
#   x = []
#   data = []
#   def my_func (x) :
#     if x in filtering :
#       return False
#     else :
#       return True

#   fit = filter(my_func,indikator)
#   for x in fit :
#     data.append(x)
#   return data

# data['indikator_filter'] = data['Indikator_normalized'].apply(stopword_removal)

# # Stemming
# def stemming(indikator) :
#   factory = StemmerFactory()
#   stemmer = factory.create_stemmer()

#   do = []
#   for w in indikator :
#     dt = stemmer.stem(w)
#     do.append(dt)

#   data_clean = []
#   d_clean = " ".join(do)
#   print(d_clean)
#   return d_clean

# data['indikator_stemming'] = data['indikator_filter'].apply(stemming)

# #tokenize data stemming - NLTK word tokenize
# def stemmed_tokenizing(indikator) :
#   return word_tokenize(indikator)

# data['indikator_stemmed_tokens'] = data['indikator_stemming'].apply(stemmed_tokenizing)

# data_clean = data.astype({'Tipe' : 'category'})
# data_clean = data.astype({'indikator_stemmed_tokens' : 'string'})

# X = data_clean['indikator_stemmed_tokens']
# y = data_clean['Tipe']

# list_indikator = np.array(X)
# list_tipe = np.array(y)
# enc = LabelEncoder()
# list_tipe = enc.fit_transform(list_tipe)

# # Saving X
# !pip install joblib
# import joblib
# joblib.dump(list_indikator, 'X_A3.sav')

# # Saving y encode
# joblib.dump(list_tipe, 'y_A3.sav')
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # eval

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import ADASYN, SMOTE
from sklearn.metrics import f1_score
import joblib

# Load data X and y
X = joblib.load('X_A3.sav')
y = joblib.load('y_A3.sav')

# Initialize and fit CountVectorizer and TfidfTransformer
cntizer = CountVectorizer(analyzer="word", max_features=1000, min_df=0.01)
X_cnt = cntizer.fit_transform(X)

tfizer = TfidfTransformer()
X_tfidf = tfizer.fit_transform(X_cnt).toarray()
X = X_tfidf

# Load new data for prediction
dt = pd.read_csv('A3.csv')
df_tes = dt['Indikator']
label = dt['Tipe']

# Transform the new data
my_X_cnt = cntizer.transform(df_tes.values.astype('U'))
my_X_tfidf = tfizer.transform(my_X_cnt).toarray()

# Initialize the result list
result = []
ads = ADASYN()
X_ads, y_ads = ads.fit_resample(X,y)

# Train the model
model = SGDClassifier(alpha=0.01, loss='perceptron', max_iter=400, penalty='l2')
model.fit(X_ads, y_ads)

# Save the model
joblib.dump(model, 'clf_A3.sav')

# Predict the new data
y_pred = model.predict(my_X_tfidf)

# Convert predictions to 'E' or 'I'
for pred in y_pred:
    if pred == 0:
        result.append('E')
    else:
        result.append('I')

# Display the predictions
for i, res in enumerate(result):
    print(f"Data {i+1}: Prediksi = {res}")
# Out:
# Data 1: Prediksi = I
# Data 2: Prediksi = I
# Data 3: Prediksi = E
# Data 4: Prediksi = E
# Data 5: Prediksi = I
# Data 6: Prediksi = I
# Data 7: Prediksi = I
# Data 8: Prediksi = I
# Data 9: Prediksi = E
# Data 10: Prediksi = E

# %%
pd.DataFrame(label)
# Out:
#   Tipe
# 0    I
# 1    I
# 2    E
# 3    E
# 4    I
# 5    E
# 6    I
# 7    I
# 8    E
# 9    E

# %%
pd.DataFrame(df_tes)
# Out:
#                                            Indikator
# 0  saya membagikan ke beberapa orang tertentu, mu...
# 1                       hanya kepada orang tertentu
# 2  Di media sosial tapi hanya untuk teman teman t...
# 3  saya lebih membagikan cerita tersebut kepada t...
# 4  mencerikan kepada orang orang terdekat seperti...
# 5  Saya akan memberitahukannya secara transparan ...
# 6  Tidak suka. Kalopun pernah ya paling cerita ke...
# 7  Saya jarang membagikan kepada siapapun. Tapi s...
# 8  saya sangat sering menunjukkan ke banyak orang...
# 9  Saya biasanya suka membagikanya ke sosial medi...

# %% [markdown]
# # Saving prepro for testing

# %%
# Load data
dt = pd.read_csv('test_E3.csv')

# casefolding
dt['Indikator'] = dt['Indikator'].str.lower()

# cleansing
def data_clean(indikator) :
  # remove tab. new line, and back slice
  indikator = indikator.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
  # remove non ASCII (emoticon,dll)
  indikator = indikator.encode('ascii', 'replace').decode('ascii')
  # remove mention, link, hashtag
  indikator = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", indikator).split())
  # remove number
  indikator = re.sub(r"\d+", "", indikator)
  # remove punct
  indikator = indikator.translate(str.maketrans("","",string.punctuation))
  # remove whitespace leading & trailing
  indikator = indikator.strip()
  # remove multiple white spacew into single white space
  indikator = re.sub('\s+', ' ', indikator)
  # remove single char
  indikator = re.sub(r"\b[a-zA-Z]\b", "", indikator)

  return indikator

dt['Indikator'] = dt['Indikator'].apply(data_clean)

# Tokenizing
def word_tokenize_wrapper(indikator) :

  return word_tokenize(indikator)

dt['Indikator'] = dt['Indikator'].apply(word_tokenize_wrapper)

# Normalization

normalized_list = pd.read_csv('normalisasi1.csv')
normalized_dict = {}

for index, row in normalized_list.iterrows() :
  if row[0] not in normalized_dict :
    normalized_dict[row[0]] = row[1]

def normalizer(indikator) :
  return [normalized_dict[term] if term in normalized_dict else term for term in indikator]

dt['Indikator'] = dt['Indikator'].apply(normalizer)

# filtering
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')


def stopword_removal (indikator):
  filtering = stopwords.words('indonesian','english')
  x = []
  data = []
  def my_func (x) :
    if x in filtering :
      return False
    else :
      return True

  fit = filter(my_func,indikator)
  for x in fit :
    data.append(x)
  return data

dt['Indikator'] = dt['Indikator'].apply(stopword_removal)

# Stemming
def stemming(indikator) :
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()

  do = []
  for w in indikator :
    dt = stemmer.stem(w)
    do.append(dt)

  data_clean = []
  d_clean = " ".join(do)
  print(d_clean)
  return d_clean

dt['Indikator'] = dt['Indikator'].apply(stemming)

#tokenize data stemming - NLTK word tokenize
def stemmed_tokenizing(indikator) :
  return word_tokenize(indikator)

dt['Indikator'] = dt['Indikator'].apply(stemmed_tokenizing)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# rencana cerita orang dekat rencana capai dapat simpan
# orang orangorang dekat beritahu umbar umbar fokus tuju bagi jarang pandai bagi orang
# bagi rencana orangorang rencana lulus sma
# suka orang orang percaya milik rencana buka usaha
# cenderung bagi teman keluarga bagi
# keep sendirim jarang tampil tuju sosmed sukses gagal gamau pressure terkadang berceita memberitahu kakak tuju capai bagi momen
# milik tuju buka bisnis jual ajak orang dek seprti teman anggap keluarga
# milik tuju rencana suka bagi teresbut orang orang orang orang dekat kenal bagi
# tuju rencana suka bagi orang media sosial hanay bagi orang jarang bagi

# %%
dt.to_csv('E3_prepro.csv',index=False)

# %% [markdown]
# # eval

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import ADASYN, SMOTE
from sklearn.metrics import f1_score
import joblib

# Load data X and y
X = joblib.load('X_E3.sav')
y = joblib.load('y_E3.sav')

# Initialize and fit CountVectorizer and TfidfTransformer
cntizer = CountVectorizer(analyzer="word", max_features=1000, min_df=0.01)
X_cnt = cntizer.fit_transform(X)

tfizer = TfidfTransformer()
X_tfidf = tfizer.fit_transform(X_cnt).toarray()
X = X_tfidf

# Load new data for prediction
dt = pd.read_csv('E3_prepro.csv')
df_tes = dt['Indikator']
label = dt['Tipe']

# Transform the new data
my_X_cnt = cntizer.transform(df_tes.values.astype('U'))
my_X_tfidf = tfizer.transform(my_X_cnt).toarray()

# Initialize the result list
result = []
ads = ADASYN()
X_ads, y_ads = ads.fit_resample(X,y)

# Train the model
model = SGDClassifier(alpha=0.01, loss='perceptron', max_iter=400, penalty='l2')
model.fit(X_ads, y_ads)

# Save the model
joblib.dump(model, 'clf_A3.sav')

# Predict the new data
y_pred = model.predict(my_X_tfidf)

# Convert predictions to 'E' or 'I'
for pred in y_pred:
    if pred == 0:
        result.append('E')
    else:
        result.append('I')

# Display the predictions
for i, res in enumerate(result):
    print(f"{res}")
# Out:
# I
# I
# I
# E
# I
# E
# I
# I
# I

# %%
pd.DataFrame(label)
# Out:
#   Tipe
# 0    I
# 1    I
# 2    I
# 3    I
# 4    I
# 5    I
# 6    I
# 7    I
# 8    I

# %%
pd.DataFrame(df_tes)
